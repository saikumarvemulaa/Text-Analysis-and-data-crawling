# %% [markdown]
# ## Data_Extraction

# %%
import csv
import requests
import pandas as pd
from bs4 import BeautifulSoup
import os

# Function to scrape data from a single website
def scrape_website(url):
    try:
        # Send a GET request to the URL
        response = requests.get(url)
        
        # Check if the request was successful
        if response.status_code == 200:
            # Parse the HTML content of the page
            soup = BeautifulSoup(response.text, 'html.parser')
            
            # Extract the article text from within the body tag
            body_content = soup.find('body')
            if body_content:
                # Remove unwanted elements such as scripts and styles
                [x.extract() for x in body_content(['script', 'style'])]
                # Extract the text
                article_text = body_content.get_text(separator='\n', strip=True)
                
                # Return the article text
                return article_text
            else:
                return "Failed to find body content"
        else:
            return f"Failed to scrape: HTTP status code {response.status_code}",
    except Exception as e:
        return f"Failed to scrape: {e}",

# Read the CSV file containing website URLs
csv_file = 'C:\\Users\\saiku\\Desktop\\Black coffee\\Input.xlsx - Sheet1.csv'  # Replace with the path to your CSV file
output_folder = 'C:\\Users\\saiku\\Desktop\\Scraped_Text_Files'  # Replace with the path to the output folder

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Open the CSV file and read the URLs from the second column
with open(csv_file, 'r', newline='') as file:
    reader = csv.reader(file)
    next(reader)  # Skip header row if it exists
    for row in reader:
        website_id = row[0]  # Assuming the URL IDs are in the first column
        website_url = row[1]  # Assuming the URLs are in the second column
        print("Scraping:", website_url)
        article_text = scrape_website(website_url)
        if isinstance(article_text, tuple):  # Check if article_text is a tuple (error message)
            print(f"Failed to scrape URL {website_url}: {article_text[0]}")
        else:
            # Write the scraped text to a text file
            filename = os.path.join(output_folder, f"{website_id}.txt")
            with open(filename, 'w', encoding='utf-8') as text_file:
                text_file.write(article_text)
            print(f"Scraped data saved to: {filename}")
        print()
# Out:
# Scraping: https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0001.txt
#
# Scraping: https://insights.blackcoffer.com/rising-it-cities-and-their-impact-on-the-economy-environment-infrastructure-and-city-life-in-future/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0002.txt
#
# Scraping: https://insights.blackcoffer.com/internet-demands-evolution-communication-impact-and-2035s-alternative-pathways/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0003.txt
#
# Scraping: https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-in-upcoming-future/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0004.txt
#
# Scraping: https://insights.blackcoffer.com/ott-platform-and-its-impact-on-the-entertainment-industry-in-future/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0005.txt
#
# Scraping: https://insights.blackcoffer.com/the-rise-of-the-ott-platform-and-its-impact-on-the-entertainment-industry-by-2040/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0006.txt
#
# Scraping: https://insights.blackcoffer.com/rise-of-cyber-crime-and-its-effects/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0007.txt
#
# Scraping: https://insights.blackcoffer.com/rise-of-internet-demand-and-its-impact-on-communications-and-alternatives-by-the-year-2035-2/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0008.txt
#
# Scraping: https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-by-the-year-2040-2/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0009.txt
#
# Scraping: https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-by-the-year-2040/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0010.txt
#
# Scraping: https://insights.blackcoffer.com/rise-of-internet-demand-and-its-impact-on-communications-and-alternatives-by-the-year-2035/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0011.txt
#
# Scraping: https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-3-2/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0012.txt
#
# Scraping: https://insights.blackcoffer.com/rise-of-e-health-and-its-impact-on-humans-by-the-year-2030/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0013.txt
#
# Scraping: https://insights.blackcoffer.com/rise-of-e-health-and-its-imapct-on-humans-by-the-year-2030-2/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0014.txt
#
# Scraping: https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-2/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0015.txt
#
# Scraping: https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-2-2/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0016.txt
#
# Scraping: https://insights.blackcoffer.com/rise-of-chatbots-and-its-impact-on-customer-support-by-the-year-2040/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0017.txt
#
# Scraping: https://insights.blackcoffer.com/rise-of-e-health-and-its-imapct-on-humans-by-the-year-2030/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0018.txt
#
# Scraping: https://insights.blackcoffer.com/how-does-marketing-influence-businesses-and-consumers/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0019.txt
#
# Scraping: https://insights.blackcoffer.com/how-advertisement-increase-your-market-value/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0020.txt
#
# Scraping: https://insights.blackcoffer.com/negative-effects-of-marketing-on-society/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0021.txt
#
# Scraping: https://insights.blackcoffer.com/how-advertisement-marketing-affects-business/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0022.txt
#
# Scraping: https://insights.blackcoffer.com/rising-it-cities-will-impact-the-economy-environment-infrastructure-and-city-life-by-the-year-2035/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0023.txt
#
# Scraping: https://insights.blackcoffer.com/rise-of-ott-platform-and-its-impact-on-entertainment-industry-by-the-year-2030/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0024.txt
#
# Scraping: https://insights.blackcoffer.com/rise-of-electric-vehicles-and-its-impact-on-livelihood-by-2040/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0025.txt
#
# Scraping: https://insights.blackcoffer.com/rise-of-electric-vehicle-and-its-impact-on-livelihood-by-the-year-2040/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0026.txt
#
# Scraping: https://insights.blackcoffer.com/oil-prices-by-the-year-2040-and-how-it-will-impact-the-world-economy/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0027.txt
#
# Scraping: https://insights.blackcoffer.com/an-outlook-of-healthcare-by-the-year-2040-and-how-it-will-impact-human-lives/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0028.txt
#
# Scraping: https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0029.txt
#
# Scraping: https://insights.blackcoffer.com/what-if-the-creation-is-taking-over-the-creator/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0030.txt
#
# Scraping: https://insights.blackcoffer.com/what-jobs-will-robots-take-from-humans-in-the-future/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0031.txt
#
# Scraping: https://insights.blackcoffer.com/will-machine-replace-the-human-in-the-future-of-work/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0032.txt
#
# Scraping: https://insights.blackcoffer.com/will-ai-replace-us-or-work-with-us/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0033.txt
#
# Scraping: https://insights.blackcoffer.com/man-and-machines-together-machines-are-more-diligent-than-humans-blackcoffe/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0034.txt
#
# Scraping: https://insights.blackcoffer.com/in-future-or-in-upcoming-years-humans-and-machines-are-going-to-work-together-in-every-field-of-work/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0035.txt
#
# Scraping: https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/
# Failed to scrape URL https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/: Failed to scrape: HTTP status code 404
#
# Scraping: https://insights.blackcoffer.com/how-machine-learning-will-affect-your-business/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0037.txt
#
# Scraping: https://insights.blackcoffer.com/deep-learning-impact-on-areas-of-e-learning/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0038.txt
#
# Scraping: https://insights.blackcoffer.com/how-to-protect-future-data-and-its-privacy-blackcoffer/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0039.txt
#
# Scraping: https://insights.blackcoffer.com/how-machines-ai-automations-and-robo-human-are-effective-in-finance-and-banking/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0040.txt
#
# Scraping: https://insights.blackcoffer.com/ai-human-robotics-machine-future-planet-blackcoffer-thinking-jobs-workplace/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0041.txt
#
# Scraping: https://insights.blackcoffer.com/how-ai-will-change-the-world-blackcoffer/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0042.txt
#
# Scraping: https://insights.blackcoffer.com/future-of-work-how-ai-has-entered-the-workplace/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0043.txt
#
# Scraping: https://insights.blackcoffer.com/ai-tool-alexa-google-assistant-finance-banking-tool-future/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0044.txt
#
# Scraping: https://insights.blackcoffer.com/ai-healthcare-revolution-ml-technology-algorithm-google-analytics-industrialrevolution/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0045.txt
#
# Scraping: https://insights.blackcoffer.com/all-you-need-to-know-about-online-marketing/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0046.txt
#
# Scraping: https://insights.blackcoffer.com/evolution-of-advertising-industry/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0047.txt
#
# Scraping: https://insights.blackcoffer.com/how-data-analytics-can-help-your-business-respond-to-the-impact-of-covid-19/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0048.txt
#
# Scraping: https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/
# Failed to scrape URL https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/: Failed to scrape: HTTP status code 404
#
# Scraping: https://insights.blackcoffer.com/environmental-impact-of-the-covid-19-pandemic-lesson-for-the-future/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0050.txt
#
# Scraping: https://insights.blackcoffer.com/how-data-analytics-and-ai-are-used-to-halt-the-covid-19-pandemic/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0051.txt
#
# Scraping: https://insights.blackcoffer.com/difference-between-artificial-intelligence-machine-learning-statistics-and-data-mining/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0052.txt
#
# Scraping: https://insights.blackcoffer.com/how-python-became-the-first-choice-for-data-science/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0053.txt
#
# Scraping: https://insights.blackcoffer.com/how-google-fit-measure-heart-and-respiratory-rates-using-a-phone/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0054.txt
#
# Scraping: https://insights.blackcoffer.com/what-is-the-future-of-mobile-apps/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0055.txt
#
# Scraping: https://insights.blackcoffer.com/impact-of-ai-in-health-and-medicine/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0056.txt
#
# Scraping: https://insights.blackcoffer.com/telemedicine-what-patients-like-and-dislike-about-it/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0057.txt
#
# Scraping: https://insights.blackcoffer.com/how-we-forecast-future-technologies/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0058.txt
#
# Scraping: https://insights.blackcoffer.com/can-robots-tackle-late-life-loneliness/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0059.txt
#
# Scraping: https://insights.blackcoffer.com/embedding-care-robots-into-society-socio-technical-considerations/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0060.txt
#
# Scraping: https://insights.blackcoffer.com/management-challenges-for-future-digitalization-of-healthcare-services/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0061.txt
#
# Scraping: https://insights.blackcoffer.com/are-we-any-closer-to-preventing-a-nuclear-holocaust/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0062.txt
#
# Scraping: https://insights.blackcoffer.com/will-technology-eliminate-the-need-for-animal-testing-in-drug-development/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0063.txt
#
# Scraping: https://insights.blackcoffer.com/will-we-ever-understand-the-nature-of-consciousness/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0064.txt
#
# Scraping: https://insights.blackcoffer.com/will-we-ever-colonize-outer-space/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0065.txt
#
# Scraping: https://insights.blackcoffer.com/what-is-the-chance-homo-sapiens-will-survive-for-the-next-500-years/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0066.txt
#
# Scraping: https://insights.blackcoffer.com/why-does-your-business-need-a-chatbot/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0067.txt
#
# Scraping: https://insights.blackcoffer.com/how-you-lead-a-project-or-a-team-without-any-technical-expertise/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0068.txt
#
# Scraping: https://insights.blackcoffer.com/can-you-be-great-leader-without-technical-expertise/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0069.txt
#
# Scraping: https://insights.blackcoffer.com/how-does-artificial-intelligence-affect-the-environment/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0070.txt
#
# Scraping: https://insights.blackcoffer.com/how-to-overcome-your-fear-of-making-mistakes-2/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0071.txt
#
# Scraping: https://insights.blackcoffer.com/is-perfection-the-greatest-enemy-of-productivity/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0072.txt
#
# Scraping: https://insights.blackcoffer.com/global-financial-crisis-2008-causes-effects-and-its-solution/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0073.txt
#
# Scraping: https://insights.blackcoffer.com/gender-diversity-and-equality-in-the-tech-industry/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0074.txt
#
# Scraping: https://insights.blackcoffer.com/how-to-overcome-your-fear-of-making-mistakes/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0075.txt
#
# Scraping: https://insights.blackcoffer.com/how-small-business-can-survive-the-coronavirus-crisis/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0076.txt
#
# Scraping: https://insights.blackcoffer.com/impacts-of-covid-19-on-vegetable-vendors-and-food-stalls/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0077.txt
#
# Scraping: https://insights.blackcoffer.com/impacts-of-covid-19-on-vegetable-vendors/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0078.txt
#
# Scraping: https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-tourism-aviation-industries/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0079.txt
#
# Scraping: https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-sports-events-around-the-world/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0080.txt
#
# Scraping: https://insights.blackcoffer.com/changing-landscape-and-emerging-trends-in-the-indian-it-ites-industry/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0081.txt
#
# Scraping: https://insights.blackcoffer.com/online-gaming-adolescent-online-gaming-effects-demotivated-depression-musculoskeletal-and-psychosomatic-symptoms/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0082.txt
#
# Scraping: https://insights.blackcoffer.com/human-rights-outlook/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0083.txt
#
# Scraping: https://insights.blackcoffer.com/how-voice-search-makes-your-business-a-successful-business/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0084.txt
#
# Scraping: https://insights.blackcoffer.com/how-the-covid-19-crisis-is-redefining-jobs-and-services/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0085.txt
#
# Scraping: https://insights.blackcoffer.com/how-to-increase-social-media-engagement-for-marketers/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0086.txt
#
# Scraping: https://insights.blackcoffer.com/impacts-of-covid-19-on-streets-sides-food-stalls/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0087.txt
#
# Scraping: https://insights.blackcoffer.com/coronavirus-impact-on-energy-markets-2/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0088.txt
#
# Scraping: https://insights.blackcoffer.com/coronavirus-impact-on-the-hospitality-industry-5/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0089.txt
#
# Scraping: https://insights.blackcoffer.com/lessons-from-the-past-some-key-learnings-relevant-to-the-coronavirus-crisis-4/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0090.txt
#
# Scraping: https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-2/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0091.txt
#
# Scraping: https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-3/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0092.txt
#
# Scraping: https://insights.blackcoffer.com/travel-and-tourism-outlook/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0093.txt
#
# Scraping: https://insights.blackcoffer.com/gaming-disorder-and-effects-of-gaming-on-health/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0094.txt
#
# Scraping: https://insights.blackcoffer.com/what-is-the-repercussion-of-the-environment-due-to-the-covid-19-pandemic-situation/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0095.txt
#
# Scraping: https://insights.blackcoffer.com/what-is-the-repercussion-of-the-environment-due-to-the-covid-19-pandemic-situation-2/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0096.txt
#
# Scraping: https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-office-space-and-co-working-industries/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0097.txt
#
# Scraping: https://insights.blackcoffer.com/contribution-of-handicrafts-visual-arts-literature-in-the-indian-economy/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0098.txt
#
# Scraping: https://insights.blackcoffer.com/how-covid-19-is-impacting-payment-preferences/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0099.txt
#
# Scraping: https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/
# Scraped data saved to: C:\Users\saiku\Desktop\Scraped_Text_Files\blackassign0100.txt

# %% [markdown]
# # Sentimental_Analysis

# %% [markdown]
# ### Cleaning using Stop Words Lists

# %%
import os
from nltk.tokenize import word_tokenize

# Function to read stop words from multiple files and combine them into a set
def read_stop_words(stop_words_files):
    combined_stop_words = set()
    for stop_words_file in stop_words_files:
        with open(stop_words_file, 'r', encoding='utf-8', errors='ignore') as f:  # Ignore errors while decoding
            words = set(f.read().splitlines())
            combined_stop_words.update(words)
    return combined_stop_words

# Function to clean text files by removing stop words
def clean_text_files(text_files_folder, stop_words, cleaned_files_folder):
    # Create the folder if it doesn't exist
    if not os.path.exists(cleaned_files_folder):
        os.makedirs(cleaned_files_folder)
    
    for filename in os.listdir(text_files_folder):
        if filename.endswith('.txt'):
            input_file_path = os.path.join(text_files_folder, filename)
            output_file_path = os.path.join(cleaned_files_folder, filename)
            
            # Read the content of the text file
            with open(input_file_path, 'r', encoding='utf-8', errors='ignore') as f:  # Ignore errors while decoding
                text = f.read()
            
            # Tokenize the text into words
            words = word_tokenize(text)
            
            # Remove stop words from the tokenized words
            filtered_words = [word for word in words if word.lower() not in stop_words]
            
            # Reconstruct the cleaned text
            cleaned_text = ' '.join(filtered_words)
            
            # Save the cleaned text to a new file
            with open(output_file_path, 'w', encoding='utf-8') as f:
                f.write(cleaned_text)

# Path to the folder containing text files
text_files_folder = 'C:\\Users\\saiku\\Desktop\\Black coffee\\Scraped_Text_Files'

# Paths to the stop words files
stop_words_files = [
    'C:\\Users\\saiku\\Desktop\\Black coffee\\stopword_file\\StopWords_Auditor.txt',
    'C:\\Users\\saiku\\Desktop\\Black coffee\\stopword_file\\StopWords_Currencies.txt',
    'C:\\Users\\saiku\\Desktop\\Black coffee\\stopword_file\\StopWords_DatesandNumbers.txt',
    'C:\\Users\\saiku\\Desktop\\Black coffee\\stopword_file\\StopWords_Generic.txt',
    'C:\\Users\\saiku\\Desktop\\Black coffee\\stopword_file\\StopWords_GenericLong.txt',
    'C:\\Users\\saiku\\Desktop\\Black coffee\\stopword_file\\StopWords_Geographic.txt',
    'C:\\Users\\saiku\\Desktop\\Black coffee\\stopword_file\\StopWords_Names.txt',
]

# Path to the folder where cleaned text files will be saved
cleaned_files_folder = 'C:\\Users\\saiku\\Desktop\\Black coffee\\Cleaned_Text_Files'

# Read stop words from multiple files
stop_words = read_stop_words(stop_words_files)

# Clean text files by removing stop words
clean_text_files(text_files_folder, stop_words, cleaned_files_folder)

print("Text files cleaned successfully and saved to:", cleaned_files_folder)
# Out:
# Text files cleaned successfully and saved to: C:\Users\saiku\Desktop\Black coffee\Cleaned_Text_Files

# %% [markdown]
# ## Creating dictionary of Positive and Negative words

# %%
def read_words_from_file(file_path):
    with open(file_path, 'r') as file:
        words = file.read().splitlines()
    return words

# Path to the text files containing positive and negative words
positive_words_file = 'C:\\Users\\saiku\\Desktop\\Black coffee\\MasterDictionary\\positive-words.txt'
negative_words_file = 'C:\\Users\\saiku\\Desktop\\Black coffee\\MasterDictionary\\negative-words.txt'

# Read positive and negative words from files
positive_words = read_words_from_file(positive_words_file)
negative_words = read_words_from_file(negative_words_file)

# Create dictionaries of positive and negative words
positive_dict = {word: True for word in positive_words}
negative_dict = {word: True for word in negative_words}

print("Positive words dictionary:", positive_dict)
print("Negative words dictionary:", negative_dict)
# Out:
# Positive words dictionary: {'a+': True, 'abound': True, 'abounds': True, 'abundance': True, 'abundant': True, 'accessable': True, 'accessible': True, 'acclaim': True, 'acclaimed': True, 'acclamation': True, 'accolade': True, 'accolades': True, 'accommodative': True, 'accomodative': True, 'accomplish': True, 'accomplished': True, 'accomplishment': True, 'accomplishments': True, 'accurate': True, 'accurately': True, 'achievable': True, 'achievement': True, 'achievements': True, 'achievible': True, 'acumen': True, 'adaptable': True, 'adaptive': True, 'adequate': True, 'adjustable': True, 'admirable': True, 'admirably': True, 'admiration': True, 'admire': True, 'admirer': True, 'admiring': True, 'admiringly': True, 'adorable': True, 'adore': True, 'adored': True, 'adorer': True, 'adoring': True, 'adoringly': True, 'adroit': True, 'adroitly': True, 'adulate': True, 'adulation': True, 'adulatory': True, 'advanced': True, 'advantage': True, 'advantageous': True, 'advantageously': True, 'advantages': True, 'adventuresome': True, 'adventurous': True, 'advocate': True, 'advocated': True, 'advocates': True, 'affability': True, 'affable': True, 'affably': True, 'affectation': True, 'affection': True, 'affectionate': True, 'affinity': True, 'affirm': True, 'affirmation': True, 'affirmative': True, 'affluence': True, 'affluent': True, 'afford': True
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import cmudict

# Load CMU Pronouncing Dictionary for syllable count
nltk.download('cmudict')
d = cmudict.dict()

# Function to count syllables in a word using CMU Pronouncing Dictionary
def syllable_count(word):
    try:
        return [len(list(y for y in x if y[-1].isdigit())) for x in d[word.lower()]][0]
    except KeyError:
        return 0  # Return 0 if the word is not found in the dictionary

# Function to calculate complex word count
def count_complex_words(words):
    complex_word_count = 0
    for word in words:
        if syllable_count(word) > 2:  # Consider words with more than 2 syllables as complex
            complex_word_count += 1
    return complex_word_count

# Function to calculate personal pronouns count
def count_personal_pronouns(text):
    pronouns = re.findall(r'\b(I|we|my|ours|us)\b', text, flags=re.IGNORECASE)
    return len(pronouns)

# Function to calculate readability metrics
def calculate_readability_metrics(text):
    sentences = sent_tokenize(text)
    words = word_tokenize(text)
    word_count = len(words)
    sentence_count = len(sentences)
    
    # Check if word count or sentence count is zero to avoid division by zero
    if word_count == 0 or sentence_count == 0:
        avg_sentence_length = 0
        percentage_complex_words = 0
        fog_index = 0
        avg_words_per_sentence = 0
    else:
        avg_sentence_length = word_count / sentence_count
        percentage_complex_words = count_complex_words(words) / word_count
        fog_index = 0.4 * (avg_sentence_length + percentage_complex_words)
        avg_words_per_sentence = word_count / sentence_count
    
    return avg_sentence_length, percentage_complex_words, fog_index, avg_words_per_sentence


# Function to analyze sentiment and calculate scores
def analyze_sentiment(text, positive_dict, negative_dict):
    words = word_tokenize(text)
    word_count = len(words)
    positive_score = sum(1 for word in words if word in positive_dict)
    negative_score = sum(1 for word in words if word in negative_dict)
    polarity_score = (positive_score - negative_score) / (positive_score + negative_score + 0.000001)
    subjectivity_score = (positive_score + negative_score) / (word_count + 0.000001)
    avg_sentence_length, percentage_complex_words, fog_index, avg_words_per_sentence = calculate_readability_metrics(text)
    complex_word_count = count_complex_words(words)
    personal_pronouns_count = count_personal_pronouns(text)
    
    # Handle division by zero error for average word length
    if word_count == 0:
        avg_word_length = 0
    else:
        avg_word_length = sum(len(word) for word in words) / word_count
    
    # Handle division by zero error for syllable per word
    if word_count == 0:
        syllable_per_word = 0
    else:
        syllable_per_word = sum(syllable_count(word) for word in words) / word_count
    
    return {
        'Positive Score': positive_score,
        'Negative Score': negative_score,
        'Polarity Score': polarity_score,
        'Subjectivity Score': subjectivity_score,
        'Avg Sentence Length': avg_sentence_length,
        'Percentage of Complex Words': percentage_complex_words,
        'Fog Index': fog_index,
        'Avg Words Per Sentence': avg_words_per_sentence,
        'Complex Word Count': complex_word_count,
        'Word Count': word_count,
        'Syllable Per Word': syllable_per_word,
        'Personal Pronouns': personal_pronouns_count,
        'Avg Word Length': avg_word_length
    }

# Path to the folder containing cleaned text files
cleaned_files_folder = 'C:\\Users\\saiku\\Desktop\\Black coffee\\Cleaned_Text_Files'

# Path to the output CSV file
output_csv_file = 'sentiment_analysis_results.csv'


# Process each cleaned text file
results = []
for filename in os.listdir(cleaned_files_folder)[:100]:  # Process only first 100 files
    if filename.endswith('.txt'):
        file_path = os.path.join(cleaned_files_folder, filename)
        with open(file_path, 'r', encoding='utf-8') as file:
            text = file.read()
        sentiment_scores = analyze_sentiment(text, positive_dict, negative_dict)
        results.append(sentiment_scores)

# Write results to CSV file
import csv
with open(output_csv_file, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['File Name'] + list(results[0].keys())
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for i, result in enumerate(results):
        writer.writerow({'File Name': f'File_{i+1}'} | result)
# Out:
# [nltk_data] Downloading package cmudict to
# [nltk_data]     C:\Users\saiku\AppData\Roaming\nltk_data...
# [nltk_data]   Package cmudict is already up-to-date!
